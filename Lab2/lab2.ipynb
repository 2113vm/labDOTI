# %%
import numpy as np
import collections
import re

# %%
def NOD(a, b):
    while a != 0 and b != 0:
        if a > b:
            a = a % b
        else:
            b = b % a
    return a + b

# %%
with open('case5', 'r', encoding='1251') as f:
    case = f.read()

# %%
ALHAVIT = set(re.findall('[а-яА-Я]', case))
ALHAVIT.add(' ')
ALHAVIT = list(ALHAVIT)

# %%
case
# Out:
# 'РАЮУИТБЮЫ ПТЦЮАШАХШСХГЦ ЭПИСЫНАУУАГРОЛТЙЧАЮУЩХДЯТПЪПЬАЕЪБРАУЖЖФААШАЭА ПЕЦВЖТОПТДФЖРДППФ АНООГДБПТЩШАЯСЯЫИЮЩЬААЭЖРАУПИЬАДЮАЫУЛЮДЯТМШВЯТОРНЦВЖЭЙПТОЮАЦЧЙЭТВХЖЭОЯТПБАЮШЕЮТВУУЪБРХПЮВАУЗХОЩСАШГС АЯЖВВПТЙЗТПАЖЮОЯПДЯЧБПИС ЖЬПФТР ПБДФФОЯРАЫЙЕАСРЕЫАЯППТВББЙУКЖНТПТГПДЯВ ЖЛГТЙПФЭШСПОЦТТЬПВВ ПОСТОХФБНРЭЬЦТТББАУОШ РЕЖЧЕЮАДЮАЮУЩХДЯТМХЛСВ ПШЦЮПТЖЫУАТЖБОНРАЩГЛВТЮАДЮАЯГПСЖЮ ППГРЮЖЖЖЮЫЙПИСЭП ЖЮШМКЦРФПЫЖШ ЖЩАЫУЛПУЯТНЮИЯЮЖЩАЩТУЮНГТРЮЕЯФОЮДЯТПЭАБЭПЭШСЮТОАЮУАЬПЩЗА ФЫУЦПОСТНПДЯЧФППВТСЮЗХШОШ РЫАЯПЕАСЮОЦ АТАЖШСЪГЩТТХМСТДЮСОЗЙЭБРФМШИРБПЪПЪ ЬДАЦЦППСЯЧЙБЖЬШКПЙУУОПРЦДСЮГЩЙАСЬЬТСЮТВЕААСЦЧОХДЯТДЫБШУАШНЦЮААЖАНЖПГЯЮПАБРВФАЬЦТОЮТРБСОНЯЬАЫЙЖАНПВЛЮАСЖЬТЙПЦГЧПИБУТГЮУРЯЙЫПБДЙТЬЪТДЮТГЧБ ЭРЯПЩАУГЭПШВААЬПФТ ПРАЫРЮНЮЫУЛАЫУТРУЦЮЭЭПРАВ БШУАЦЙШ ЙПИС  БЙЪТО БУУАШАЮУСВЗЮАТБЙРБПЪПЪ ПУПРГПАЖХУАША ВЙОУЦЮ ПНЯШДЮАЮААТАБЮФЖБЦТЖАМЩТИРВЬУДЮССГТВЕЩДЖПТХШМРУМТЙЧАБШДЮАЭАЖУПРБЙАЭЭУАЪБЫАЖПМЩФППФ АУ ЖТЮЖЭЙЦТГАЖ АЛЮСЮШКЗЖРБСЮЩГТОШЛСЭАШНЦ ЙПНЯШДЮАЮШАВРЯЯЙЭБВОАШВЯТЦЮУПТ ПГЦГЭЬБРЕГРЗСРАШАЬРВЫЯРГПЖЙЮЫУХМЦЬАЭПРХААЙЦТИТБЮЫЖПГБДФЯЙВОАЯПЬУДРЯРЫИЫЙИ ЙЬАЩТГПНЯЫАЫЖВУАЭЖ ВЙЫЙЗ ЬЬАБТЙАУЩ ОКНРЯПШНРБПЖУЦ ЙХНРЫАЯСЯЙАУПХЕАЭППФСОАБШМЮАЮШОРССЧПТПРГМХЕГШУПБЮШЛФПВТЛЮЖФААЬЬР ЖПРЯЯЖИБЦЯАЯПЬУДР РШДЮАЩЪМШЩЮЫНПГ ВПЖЖЭТФТЖАСЖЬАЗЫУРУЦЮ ПШВААЮОР ЙЖЖФААЯСЦЧПАФХЫУХММ ПУПРББЬ ВЫАШГС БПРЦДСЮГЩЙБПВЦЮЛШОСТГПТЦФЖПОЦТИРЛЬРШРЖВТГПТСЯПЬАХШМХАУТСВЛЯБЙАЙРЦАСЖЬЭЙЭБР БФАЫУЗФПЪТРЮГЦГУШЯРВФЪПОТБТУЯВБПОСЧРШТС ППТЬНЩЭПРЯОЮЯРАУПУСЭПЩАВААЮТЯФЬПШЩ АШМЩТИТБЮЫЖПЙРЪБУМСХОКЖРФФЪГЛТЙЬЖЮЫАШАДУНШМЩЫАТЬ ЫТКГСШНПЕЬСАЫЯТАРКУЮНЦПЙШНТЪБВШМХКРГНЮУАЫУХММТСРТБЭБЧБЮТВКМРШНВАВЫУВМПВОКНРГПТЖВ ЙЪПЭТБПДР АТЬБДСХМ'

# %%
def get_list_ngrams(lenght, case):
    return list({case[i: i + lenght] for i in range(0, len(case)-lenght)})

# %%
def find_indexs_pattern(pattern, case=case):
    return [pat.span()[0] for pat in re.finditer(pattern, case)]

# %%
def get_good_ngrams(lenght):
    d = {pattern: find_indexs_pattern(pattern, case) for pattern in get_list_ngrams(lenght, case)}
    return list(filter(lambda item: len(item[1]) > 1, d.items()))

# %%
r = get_good_ngrams(9)

# %%
res = [get_good_ngrams(l) for l in range(3, 10)]

# %%
def minus(lst):
    return [lst[i] - lst[i - 1] for i in range(1, len(lst))]

# %%
res_minus = [[(pat[0], minus(pat[1])) for pat in r] for r in res]

# %%
res_minus
# Out:
# [[('АХШ', [1240]),
#   ('ТЙП', [360]),
#   ('ШУА', [130]),
#   ('ЮАА', [194]),
#   ('АЬП', [230]),
#   ('БЙА', [440]),
#   ('ЮДЯ', [295]),
#   ('ГЩЙ', [670]),
#   ('РЦД', [670]),
#   ('ЙПИ', [340]),
#   (' ПУ', [450]),
#   ('ВАА', [500, 180]),
#   ('ГЦГ', [375]),
#   ('ЕАС', [245]),
#   ('ШГС', [1020]),
#   ('ШМХ', [180]),
#   ('ТСЮ', [90]),
#   ('ТИР', [450]),
#   ('ТДЮ', [150]),
#   ('РЫА', [575]),
#   ('КНР', [450]),
#   ('ЮТВ', [390, 907]),
#   ('ПРА', [21]),
#   ('ПДЯ', [50, 200]),
#   ('ЪПЪ', [225]),
#   ('ШВЯ', [780]),
#   ('ШДЮ', [50, 75, 235]),
#   ('ЮГЩ', [670]),
#   ('РВФ', [710]),
#   ('БШУ', [130]),
#   ('ОЦТ', [965]),
#   ('ПЬА', [1203]),
#   ('ЭБР', [775]),
#   ('СЦЧ', [620]),
#   ('ЙЧА', [775]),
#   ('УДР', [140]),
#   ('ЩХД', [270]),
#   (' ЙП', [180]),
#   ('ЫЖП', [400]),
#   ('ФПП', [384]),
#   ('ТЦЮ', [902]),
#   ('ЯШД', [125]),
#   ('ПИС', [185, 160, 340]),
#   ('АУП', [941, 284]),
#   ('ЙЦТ', [105]),
#   ('ЮУА', [1008]),
#   ('ЯТП', [110, 265]),
#   ('ИТБ', [960, 400]),
#   ('АЫЙ', [380]),
#   ('ВЯТ', [780]),
#   ('Ф А', [760]),
#   ('РБП', [225, 300]),
#   ('АШГ', [1020]),
#   ('ТИТ', [400]),
#   ('ПРБ', [370]),
#   ('ШНЦ', [310]),
#   ('ПУП', [450]),
#   ('ТЖА', [367]),
#   ('АЫУ', [270, 295, 600, 161]),
#   ('В П', [45]),
#   ('ЬПФ', [455]),
#   ('ПЪП', [465, 225]),
#   ('ЖФА', [1040, 75]),
#   ('ДР ', [372]),
#   ('РЯЯ', [210]),
#   ('ПТЦ', [1220]),
#   ('РАУ', [55, 1225]),
#   ('ГС ', [1020]),
#   ('ХШМ', [450]),
#   ('ППФ', [760, 217]),
#   ('ОСТ', [170, 775]),
#   ('АЩТ', [590]),
#   ('АЭЖ', [900]),
#   ('ППТ', [1084]),
#   ('ПРГ', [335]),
#   ('ЙАУ', [29]),
#   ('ПЬУ', [140]),
#   ('АЭП', [105]),
#   ('ТРЮ', [880]),
#   ('ЮУЩ', [270]),
#   ('УЮН', [1017]),
#   ('ОКН', [450]),
#   ('ПЪ ', [225]),
#   ('ЖПГ', [385]),
#   ('АСЖ', [533, 122]),
#   ('ФАА', [1040, 75]),
#   ('ТОЮ', [455]),
#   ('АЮШ', [735, 175]),
#   ('ЫУЛ', [270, 291]),
#   ('ПВТ', [635]),
#   ('АЮУ', [40, 270, 125, 290]),
#   ('ЮАД', [40]),
#   ('ЩТИ', [575]),
#   ('ПШВ', [500]),
#   ('ДЮА', [190, 40, 420, 50, 75, 235]),
#   ('ПБД', [420]),
#   ('ПАЖ', [550]),
#   ('БПЪ', [225]),
#   ('ДЮС', [295]),
#   ('ЮЫЖ', [400]),
#   ('ДСЮ', [670]),
#   ('ЯРА', [1109]),
#   ('Ш Р', [170]),
#   ('УПР', [80, 370]),
#   ('АДЮ', [190, 40]),
#   ('ВОА', [70]),
#   ('ПФ ', [760]),
#   ('ПЩА', [685]),
#   ('ПОС', [170, 865]),
#   ('РУЦ', [470]),
#   ('ЫУХ', [240, 260]),
#   ('РАЫ', [448]),
#   ('АША', [50, 660, 30, 180, 460]),
#   ('ЦТИ', [275]),
#   ('ДЯЧ', [250]),
#   ('АШН', [310]),
#   ('ХММ', [260]),
#   ('ААЬ', [435]),
#   ('СЖЬ', [533, 122]),
#   ('ТЙЧ', [775]),
#   ('ПТЖ', [1155]),
#   ('ЮАЮ', [460, 125, 175]),
#   ('Ю П', [406, 400]),
#   ('БЮЫ', [960, 400]),
#   ('АТА', [290]),
#   ('СЭП', [970]),
#   ('ЖАН', [31]),
#   (' АТ', [1015]),
#   ('ЖЖФ', [1115]),
#   ('АТЬ', [95]),
#   ('УХМ', [240, 260]),
#   ('БДФ', [750]),
#   ('ЮЫУ', [265]),
#   ('АЯС', [950, 130]),
#   ('ЯПЬ', [140, 133]),
#   ('МЩТ', [575]),
#   ('ЖЮЫ', [1025]),
#   ('ЦТТ', [20]),
#   ('Т П', [245]),
#   ('УЩХ', [270]),
#   ('ЛТЙ', [1350]),
#   ('УУА', [691]),
#   ('ЭПР', [260, 375]),
#   (' ВЙ', [255]),
#   ('НЯШ', [125]),
#   ('АЭА', [755]),
#   ('ЪБР', [115]),
#   ('Ц Й', [155]),
#   ('ПРЦ', [670]),
#   ('ШМЩ', [40]),
#   ('ТВЕ', [243]),
#   ('ЖЭЙ', [715]),
#   ('РЯП', [375]),
#   ('СЮТ', [122]),
#   ('ЖЩА', [15]),
#   ('ААЮ', [180]),
#   ('ПРЯ', [221]),
#   ('ШВА', [500]),
#   ('ОШ ', [170]),
#   ('ЦДС', [670]),
#   ('РГП', [195, 540]),
#   ('АБШ', [250]),
#   ('ЫАШ', [190]),
#   ('ХДЯ', [270, 250]),
#   ('ЯСЯ', [950]),
#   ('ТБЮ', [960, 400]),
#   ('ИС ', [500]),
#   ('ГПТ', [20, 234]),
#   ('ПНЯ', [125, 110]),
#   ('ЙЭБ', [400, 375]),
#   (' ПШ', [840]),
#   ('ДЯТ', [80, 190, 105, 145]),
#   ('ЦЮА', [565]),
#   ('ПОЦ', [965]),
#   ('ЦЮ ', [400]),
#   ('ЯТМ', [190]),
#   ('СЮГ', [670]),
#   ('ЬУД', [190, 140]),
#   (' ПП', [965]),
#   ('АЯП', [236, 505, 140]),
#   ('ЭШС', [163]),
#   ('ЦВЖ', [65]),
#   ('ЫАЯ', [236, 575]),
#   ('УАШ', [150, 30]),
#   ('РБС', [270]),
#   ('УЦЮ', [70, 400]),
#   ('ТГП', [745, 230, 20]),
#   ('ПФТ', [455]),
#   ('ЬЦТ', [305])],
#  [('СЮГЩ', [670]),
#   ('ДЮАЮ', [460, 125]),
#   ('АШНЦ', [310]),
#   ('ТБЮЫ', [960, 400]),
#   ('АЮУЩ', [270]),
#   ('ДЯТП', [375]),
#   ('ЩХДЯ', [270]),
#   ('ЪПЪ ', [225]),
#   ('ЬУДР', [140]),
#   ('РБПЪ', [225]),
#   ('ЖЖФА', [1115]),
#   ('НЯШД', [125]),
#   ('ПФ А', [760]),
#   ('ПНЯШ', [125]),
#   ('АДЮА', [190, 40]),
#   ('РАУП', [1225]),
#   ('ШВЯТ', [780]),
#   ('ЮГЩЙ', [670]),
#   ('ОКНР', [450]),
#   ('ПШВА', [500]),
#   ('ЖФАА', [1040, 75]),
#   ('ВААЮ', [180]),
#   ('УЦЮ ', [400]),
#   ('АСЖЬ', [533, 122]),
#   ('ИТБЮ', [960, 400]),
#   ('АЫУЛ', [270]),
#   ('ЫУХМ', [240, 260]),
#   ('БПЪП', [225]),
#   ('ТИТБ', [400]),
#   ('ХДЯТ', [270, 250]),
#   ('ЫАЯП', [236]),
#   ('ПОЦТ', [965]),
#   ('ОШ Р', [170]),
#   ('УПРБ', [370]),
#   ('ШГС ', [1020]),
#   ('ШДЮА', [50, 75, 235]),
#   (' ПУП', [450]),
#   ('РЫАЯ', [575]),
#   ('ЦЮ П', [400]),
#   ('УХММ', [260]),
#   ('ЮДЯТ', [295]),
#   ('ТГПТ', [20]),
#   ('ПЪПЪ', [225]),
#   ('ППФ ', [760]),
#   ('УЩХД', [270]),
#   ('УАША', [30]),
#   ('ДЯТМ', [190]),
#   ('ЮАДЮ', [40]),
#   ('ЙПИС', [340]),
#   ('ПДЯЧ', [250]),
#   ('ПЬУД', [140]),
#   ('ЮАЮШ', [175]),
#   ('ТЙЧА', [775]),
#   ('ЙЭБР', [775]),
#   ('РЦДС', [670]),
#   ('РУЦЮ', [470]),
#   ('ЯПЬУ', [140]),
#   ('ПОСТ', [170]),
#   ('БШУА', [130]),
#   ('ШВАА', [500]),
#   ('МЩТИ', [575]),
#   ('ПИС ', [500]),
#   ('ЯШДЮ', [125]),
#   ('ДСЮГ', [670]),
#   ('ЬПФТ', [455]),
#   ('АЯСЯ', [950]),
#   ('ПРЦД', [670]),
#   ('ЮУЩХ', [270]),
#   ('ПУПР', [450]),
#   ('АЯПЬ', [140]),
#   ('ЦДСЮ', [670]),
#   ('БЮЫЖ', [400]),
#   ('ЮЫЖП', [400]),
#   ('АШГС', [1020])],
#  [('УЩХДЯ', [270]),
#   ('НЯШДЮ', [125]),
#   ('РБПЪП', [225]),
#   ('ДСЮГЩ', [670]),
#   ('ЫУХММ', [260]),
#   ('ЯШДЮА', [125]),
#   ('ЩХДЯТ', [270]),
#   ('ШДЮАЮ', [125]),
#   (' ПУПР', [450]),
#   ('БЮЫЖП', [400]),
#   ('ПЪПЪ ', [225]),
#   ('СЮГЩЙ', [670]),
#   ('ПНЯШД', [125]),
#   ('ЖЖФАА', [1115]),
#   ('ПШВАА', [500]),
#   ('ЮУЩХД', [270]),
#   ('АЮУЩХ', [270]),
#   ('ЯПЬУД', [140]),
#   ('ППФ А', [760]),
#   ('УЦЮ П', [400]),
#   ('ИТБЮЫ', [960, 400]),
#   ('АШГС ', [1020]),
#   ('ЮАДЮА', [40]),
#   ('АЯПЬУ', [140]),
#   ('РЦДСЮ', [670]),
#   ('ПЬУДР', [140]),
#   ('ЦДСЮГ', [670]),
#   ('ТИТБЮ', [400]),
#   ('БПЪПЪ', [225]),
#   ('ПРЦДС', [670]),
#   ('ТБЮЫЖ', [400])],
#  [('БПЪПЪ ', [225]),
#   ('ПРЦДСЮ', [670]),
#   ('ДСЮГЩЙ', [670]),
#   ('ПНЯШДЮ', [125]),
#   ('РБПЪПЪ', [225]),
#   ('ЯПЬУДР', [140]),
#   ('ИТБЮЫЖ', [400]),
#   ('НЯШДЮА', [125]),
#   ('АЯПЬУД', [140]),
#   ('ЦДСЮГЩ', [670]),
#   ('ЯШДЮАЮ', [125]),
#   ('ТИТБЮЫ', [400]),
#   ('УЩХДЯТ', [270]),
#   ('АЮУЩХД', [270]),
#   ('РЦДСЮГ', [670]),
#   ('ЮУЩХДЯ', [270]),
#   ('ТБЮЫЖП', [400])],
#  [('АЯПЬУДР', [140]),
#   ('ПНЯШДЮА', [125]),
#   ('РЦДСЮГЩ', [670]),
#   ('ТИТБЮЫЖ', [400]),
#   ('ПРЦДСЮГ', [670]),
#   ('РБПЪПЪ ', [225]),
#   ('НЯШДЮАЮ', [125]),
#   ('ЦДСЮГЩЙ', [670]),
#   ('АЮУЩХДЯ', [270]),
#   ('ЮУЩХДЯТ', [270]),
#   ('ИТБЮЫЖП', [400])],
#  [('ПНЯШДЮАЮ', [125]),
#   ('РЦДСЮГЩЙ', [670]),
#   ('ПРЦДСЮГЩ', [670]),
#   ('ТИТБЮЫЖП', [400]),
#   ('АЮУЩХДЯТ', [270])],
#  [('ПРЦДСЮГЩЙ', [670])]]

# %%
lenghts = []
[[lenghts.extend(_) for _ in i] for i in [[r[1]for r in res_] for res_ in res_minus]]
# Out:
# [[None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [None, None, None, None, None, None, None, None, None, None, None],
#  [None, None, None, None, None],
#  [None]]

# %%
c = collections.Counter(lenghts)

# %%
sorted(c.items(), key=lambda item: item[1], reverse=True)
# Out:
# [(670, 28),
#  (400, 28),
#  (270, 24),
#  (125, 19),
#  (225, 15),
#  (140, 15),
#  (450, 10),
#  (500, 8),
#  (40, 8),
#  (190, 8),
#  (260, 7),
#  (180, 6),
#  (1020, 6),
#  (575, 6),
#  (75, 6),
#  (775, 6),
#  (960, 6),
#  (760, 6),
#  (170, 6),
#  (375, 5),
#  (50, 5),
#  (250, 5),
#  (130, 4),
#  (295, 4),
#  (965, 4),
#  (455, 4),
#  (122, 4),
#  (20, 4),
#  (340, 3),
#  (780, 3),
#  (235, 3),
#  (105, 3),
#  (370, 3),
#  (310, 3),
#  (1040, 3),
#  (533, 3),
#  (175, 3),
#  (240, 3),
#  (30, 3),
#  (460, 3),
#  (1115, 3),
#  (950, 3),
#  (236, 3),
#  (230, 2),
#  (245, 2),
#  (150, 2),
#  (110, 2),
#  (265, 2),
#  (1225, 2),
#  (290, 2),
#  (420, 2),
#  (80, 2),
#  (70, 2),
#  (470, 2),
#  (1240, 1),
#  (360, 1),
#  (194, 1),
#  (440, 1),
#  (90, 1),
#  (390, 1),
#  (907, 1),
#  (21, 1),
#  (200, 1),
#  (710, 1),
#  (1203, 1),
#  (620, 1),
#  (384, 1),
#  (902, 1),
#  (185, 1),
#  (160, 1),
#  (941, 1),
#  (284, 1),
#  (1008, 1),
#  (380, 1),
#  (300, 1),
#  (367, 1),
#  (600, 1),
#  (161, 1),
#  (45, 1),
#  (465, 1),
#  (372, 1),
#  (210, 1),
#  (1220, 1),
#  (55, 1),
#  (217, 1),
#  (590, 1),
#  (900, 1),
#  (1084, 1),
#  (335, 1),
#  (29, 1),
#  (880, 1),
#  (1017, 1),
#  (385, 1),
#  (735, 1),
#  (291, 1),
#  (635, 1),
#  (550, 1),
#  (1109, 1),
#  (685, 1),
#  (865, 1),
#  (448, 1),
#  (660, 1),
#  (275, 1),
#  (435, 1),
#  (1155, 1),
#  (406, 1),
#  (970, 1),
#  (31, 1),
#  (1015, 1),
#  (95, 1),
#  (750, 1),
#  (133, 1),
#  (1025, 1),
#  (1350, 1),
#  (691, 1),
#  (255, 1),
#  (755, 1),
#  (115, 1),
#  (155, 1),
#  (243, 1),
#  (715, 1),
#  (15, 1),
#  (221, 1),
#  (195, 1),
#  (540, 1),
#  (234, 1),
#  (840, 1),
#  (145, 1),
#  (565, 1),
#  (505, 1),
#  (163, 1),
#  (65, 1),
#  (745, 1),
#  (305, 1)]

# %%
NOD(75, 225)
# Out:
# 75

# %%
def count(word, s):
    return collections.Counter(re.findall(word, s))[word]

def I(s):
    n = len(s)
    return sum([count(alh, s)*(count(alh, s) - 1) / (n * (n - 1)) for alh in ALHAVIT])

# %%
I(case)
# Out:
# 0.04199349472272381

# %%
def get_n_word(n):
    return ''.join([case[i] for i in range(0, len(case), n)])

# %%
# 0.0553. 13
I(get_n_word(20))
# Out:
# 0.05684210526315789

# %%
min_ = 999
min_n = 0
for i in range(1, len(case)):
    if abs(I(get_n_word(i)) - 0.0553) < min_:
        min_ = abs(I(get_n_word(i)) - 0.0553)
        min_n = i
        print(min_n, min_)
# Out:
# 1 0.013306505277276191
# 2 0.012683551558575618
# 3 0.011910932017457021
# 6 0.010115658002908999
# 7 0.009305167958656331
# 13 0.00312608695652173
# 20 0.0015421052631578863
# 40 0.00017652916073968017

# %%
min_n
# Out:
# 40

# %%
len_key = 20

# %%
[sorted(collections.Counter(get_n_word(n=n)).items(), 
        key=lambda item: item[1], 
        reverse=True)[:2] for n in range(1, len(case))]
# Out:
# [[('А', 135), ('П', 120)],
#  [('А', 73), ('П', 62)],
#  [('А', 44), ('Т', 38)],
#  [('А', 37), ('П', 33)],
#  [('П', 54), ('Ю', 37)],
#  [('П', 25), ('А', 23)],
#  [('П', 22), ('А', 19)],
#  [('А', 17), ('П', 17)],
#  [('А', 18), ('Р', 12)],
#  [('П', 27), ('Ю', 18)],
#  [('А', 13), ('Т', 11)],
#  [('П', 15), ('А', 11)],
#  [('Т', 13), ('П', 13)],
#  [('А', 11), ('П', 10)],
#  [('П', 16), ('Ю', 14)],
#  [('А', 11), ('П', 6)],
#  [('А', 10), ('П', 8)],
#  [('А', 8), ('П', 7)],
#  [('П', 8), ('У', 8)],
#  [('П', 11), ('Ю', 9)],
#  [('П', 8), ('Ю', 7)],
#  [('П', 7), ('А', 6)],
#  [('П', 8), (' ', 6)],
#  [('П', 9), ('Т', 6)],
#  [('Ю', 10), ('П', 9)],
#  [('Т', 8), ('Ш', 6)],
#  [('А', 7), ('Т', 5)],
#  [('П', 7), ('У', 5)],
#  [('А', 8), ('О', 4)],
#  [('П', 10), ('Ю', 6)],
#  [('Т', 5), ('Р', 4)],
#  [('А', 5), ('П', 4)],
#  [('А', 6), ('Т', 5)],
#  [('А', 7), ('Ш', 4)],
#  [('П', 8), ('Ю', 7)],
#  [('А', 5), ('П', 4)],
#  [('Ж', 4), ('Ш', 4)],
#  [('У', 4), ('Ь', 4)],
#  [('Т', 7), ('Й', 4)],
#  [('П', 6), ('Ю', 5)],
#  [('А', 5), ('Р', 4)],
#  [('П', 5), ('Ю', 4)],
#  [('Р', 5), ('А', 5)],
#  [('А', 4), ('Ш', 3)],
#  [('П', 7), ('Х', 6)],
#  [('П', 4), ('Р', 3)],
#  [('Р', 3), ('Й', 3)],
#  [('П', 4), ('А', 4)],
#  [('Р', 4), ('П', 2)],
#  [('Ю', 7), ('Ш', 3)],
#  [('П', 3), ('Т', 3)],
#  [('Ж', 4), ('Ш', 3)],
#  [('П', 5), ('Р', 3)],
#  [('А', 4), ('П', 3)],
#  [('Ю', 3), ('Ь', 3)],
#  [('У', 5), ('П', 3)],
#  [('Р', 5), ('У', 4)],
#  [('А', 5), ('Р', 2)],
#  [('П', 5), ('А', 3)],
#  [('П', 5), ('Ю', 4)],
#  [('Ж', 3), ('Ы', 3)],
#  [('Р', 4), ('Ю', 2)],
#  [('А', 4), ('Р', 2)],
#  [('А', 5), ('Р', 2)],
#  [('П', 7), ('Ш', 4)],
#  [('Т', 3), ('А', 2)],
#  [('Р', 3), ('Ж', 3)],
#  [('А', 4), ('Р', 2)],
#  [('Р', 3), (' ', 3)],
#  [('П', 4), ('Ю', 3)],
#  [('П', 3), ('С', 3)],
#  [('П', 2), ('Н', 2)],
#  [('Р', 3), ('В', 2)],
#  [('Р', 3), ('П', 3)],
#  [('П', 3), ('Р', 2)],
#  [('Р', 2), ('О', 2)],
#  [('В', 2), ('Ю', 2)],
#  [('Т', 4), ('Ю', 3)],
#  [('Т', 3), ('Р', 2)],
#  [('Х', 2), ('Ю', 2)],
#  [('Р', 2), ('Ю', 2)],
#  [('Ю', 3), ('А', 3)],
#  [('Р', 3), ('Т', 3)],
#  [('П', 4), ('Ю', 3)],
#  [('П', 3), ('Ш', 3)],
#  [('Р', 4), ('А', 3)],
#  [('А', 3), ('Р', 2)],
#  [('А', 2), ('В', 2)],
#  [('Р', 2), ('Ж', 2)],
#  [('П', 4), ('Х', 3)],
#  [('Т', 3), ('Р', 2)],
#  [('П', 4), ('А', 2)],
#  [('Р', 3), (' ', 2)],
#  [('С', 2), ('Ш', 2)],
#  [('П', 4), ('Х', 3)],
#  [('П', 3), ('Т', 2)],
#  [('Р', 3), (' ', 3)],
#  [('Р', 2), ('А', 2)],
#  [('Ы', 3), ('А', 2)],
#  [('Ю', 4), ('Ш', 3)],
#  [('Р', 2), ('Э', 2)],
#  [('Т', 3), ('Я', 2)],
#  [('Р', 3), ('Д', 2)],
#  [('Т', 2), ('Р', 1)],
#  [('П', 3), ('Ю', 2)],
#  [('Р', 2), ('П', 2)],
#  [('Ж', 2), ('П', 2)],
#  [('А', 3), ('П', 2)],
#  [('Р', 2), ('А', 2)],
#  [('Ю', 2), ('Ш', 2)],
#  [('Р', 2), ('Б', 2)],
#  [('Р', 2), ('Ф', 2)],
#  [('Р', 2), ('Н', 2)],
#  [('Р', 3), ('У', 3)],
#  [('П', 5), ('Р', 2)],
#  [('Р', 2), ('Е', 2)],
#  [('А', 3), ('Ш', 2)],
#  [('П', 4), ('Р', 2)],
#  [('А', 3), ('Р', 1)],
#  [('Ю', 3), ('П', 3)],
#  [('А', 3), ('П', 2)],
#  [('Ы', 2), ('Ж', 2)],
#  [('Р', 2), ('Й', 2)],
#  [('Р', 2), ('С', 2)],
#  [('Ю', 3), ('П', 3)],
#  [('Р', 1), ('Д', 1)],
#  [('Ц', 2), ('Й', 2)],
#  [('Р', 2), ('Ы', 2)],
#  [('Р', 2), ('А', 2)],
#  [('Ш', 3), ('Ж', 3)],
#  [('П', 2), ('Р', 1)],
#  [('Р', 1), ('Я', 1)],
#  [('Р', 2), ('Т', 2)],
#  [('Р', 2), ('О', 1)],
#  [('Р', 3), ('П', 3)],
#  [('Ц', 2), ('Ш', 2)],
#  [('П', 2), ('Р', 1)],
#  [('Р', 3), ('Ь', 2)],
#  [('Я', 2), ('Т', 2)],
#  [('П', 2), ('Я', 2)],
#  [('Р', 2), ('Й', 2)],
#  [('П', 2), ('Т', 2)],
#  [('П', 3), ('Т', 2)],
#  [('Н', 2), ('Р', 1)],
#  [('Р', 2), ('Ю', 1)],
#  [('А', 2), ('Б', 2)],
#  [('Р', 1), ('Ц', 1)],
#  [('Р', 3), ('Ч', 1)],
#  [('У', 3), ('Р', 1)],
#  [('Ю', 2), ('Р', 1)],
#  [('Р', 2), ('Т', 2)],
#  [('Р', 1), ('В', 1)],
#  [('Р', 1), ('Х', 1)],
#  [('В', 2), ('Р', 1)],
#  [('Р', 3), ('Ю', 2)],
#  [('Ю', 2), ('А', 2)],
#  [('Р', 2), ('А', 2)],
#  [('Р', 2), ('Т', 2)],
#  [('Р', 2), ('П', 1)],
#  [('Х', 2), ('Р', 1)],
#  [('Р', 2), ('У', 2)],
#  [('Р', 2), ('Ю', 1)],
#  [('Р', 2), ('Ш', 2)],
#  [('Ю', 2), ('Р', 1)],
#  [('Т', 2), ('Р', 1)],
#  [('Т', 2), ('А', 2)],
#  [('А', 3), ('Я', 2)],
#  [('У', 2), ('Ж', 2)],
#  [('Р', 3), ('У', 1)],
#  [('Р', 2), ('Ш', 2)],
#  [('Р', 2), ('Б', 2)],
#  [('Р', 3), ('А', 2)],
#  [('Р', 2), ('Х', 1)],
#  [('П', 2), ('Й', 2)],
#  [('Ю', 3), ('Ш', 2)],
#  [('Р', 1), ('В', 1)],
#  [('П', 2), ('Р', 1)],
#  [('Р', 2), ('Ж', 2)],
#  [('Р', 1), ('З', 1)],
#  [('Х', 3), ('П', 2)],
#  [('Р', 2), ('О', 1)],
#  [('Р', 1), ('Щ', 1)],
#  [('Ю', 2), ('Р', 1)],
#  [('А', 2), ('Р', 1)],
#  [('П', 2), ('Ю', 2)],
#  [('Р', 3), ('Г', 1)],
#  [('С', 2), ('Р', 1)],
#  [('О', 2), ('Р', 1)],
#  [('А', 2), ('Р', 1)],
#  [('Р', 1), ('Я', 1)],
#  [('Р', 3), ('Ж', 2)],
#  [('П', 2), ('А', 2)],
#  [('Т', 2), ('Р', 1)],
#  [(' ', 3), ('П', 2)],
#  [('Т', 2), ('Р', 1)],
#  [('Р', 2), ('Ж', 2)],
#  [('Р', 2), ('З', 1)],
#  [('Ы', 2), ('Р', 1)],
#  [('П', 2), ('Р', 1)],
#  [('Ю', 2), ('Р', 1)],
#  [('Ж', 2), ('Р', 1)],
#  [('Н', 2), ('Р', 1)],
#  [('А', 2), ('Р', 1)],
#  [('Р', 1), ('Я', 1)],
#  [('П', 3), ('Ю', 2)],
#  [('Р', 2), ('Д', 1)],
#  [('Р', 2), ('Я', 1)],
#  [('Т', 2), ('Р', 1)],
#  [('Б', 2), ('Р', 1)],
#  [('П', 2), ('Р', 1)],
#  [('П', 2), ('Р', 1)],
#  [('Р', 2), ('П', 2)],
#  [('Р', 1), (' ', 1)],
#  [('Б', 2), ('Р', 1)],
#  [('Р', 2), ('Ь', 1)],
#  [('Т', 2), ('Р', 1)],
#  [('Р', 2), ('Т', 2)],
#  [('Р', 2), ('Т', 2)],
#  [('Р', 3), ('У', 1)],
#  [('Ш', 2), ('Р', 1)],
#  [('Р', 1), ('П', 1)],
#  [('Р', 2), ('Б', 1)],
#  [('А', 2), ('Р', 1)],
#  [('Ф', 2), ('Р', 1)],
#  [('Р', 2), ('П', 2)],
#  [('Р', 1), ('О', 1)],
#  [('Н', 2), ('Р', 1)],
#  [('Р', 2), ('Д', 1)],
#  [('Р', 1), ('А', 1)],
#  [('Р', 2), ('П', 2)],
#  [('Р', 1), ('Й', 1)],
#  [('Р', 2), ('Е', 2)],
#  [('Р', 1), ('А', 1)],
#  [('Ш', 2), ('А', 2)],
#  [('Р', 2), ('Ш', 1)],
#  [('Р', 2), ('Е', 2)],
#  [('Ы', 2), ('А', 2)],
#  [('Р', 1), ('А', 1)],
#  [('Р', 1), ('Я', 1)],
#  [('Р', 1), ('П', 1)],
#  [('У', 2), ('Р', 1)],
#  [('А', 2), ('Р', 1)],
#  [('Р', 1), ('В', 1)],
#  [('Р', 1), ('Б', 1)],
#  [('Б', 2), ('Р', 1)],
#  [('Р', 1), ('Й', 1)],
#  [('Р', 2), ('П', 2)],
#  [('Р', 2), ('К', 1)],
#  [('Р', 3), ('Ж', 1)],
#  [('П', 2), ('Р', 1)],
#  [('Р', 1), ('Т', 1)],
#  [('Р', 1), ('П', 1)],
#  [('Р', 1), ('Т', 1)],
#  [('Р', 1), ('Г', 1)],
#  [('П', 2), ('Р', 1)],
#  [('Р', 2), ('Д', 1)],
#  [('Р', 1), ('Я', 1)],
#  [('Р', 2), ('В', 1)],
#  [(' ', 2), ('Р', 1)],
#  [('Ж', 3), ('Р', 1)],
#  [('Р', 1), ('Л', 1)],
#  [('Р', 1), ('Г', 1)],
#  [('Р', 1), ('Т', 1)],
#  [('Р', 1), ('Й', 1)],
#  [('П', 2), ('Р', 1)],
#  [('Р', 1), ('Ф', 1)],
#  [('Р', 1), ('Э', 1)],
#  [('Р', 1), ('Ш', 1)],
#  [('С', 2), ('Р', 1)],
#  [('Р', 2), ('П', 2)],
#  [('Р', 1), ('О', 1)],
#  [('Ш', 2), ('Р', 1)],
#  [('Т', 2), ('Р', 1)],
#  [('П', 2), ('Р', 1)],
#  [('У', 2), ('Р', 1)],
#  [('Р', 1), ('П', 1)],
#  [('Р', 1), ('В', 1)],
#  [('Р', 1), ('В', 1)],
#  [('Р', 1), (' ', 1)],
#  [('П', 2), ('Р', 1)],
#  [('Р', 1), ('О', 1)],
#  [('Р', 1), ('С', 1)],
#  [('Р', 1), ('Т', 1)],
#  [('Т', 2), ('Р', 1)],
#  [('Р', 1), ('Х', 1)],
#  [('П', 2), ('Р', 1)],
#  [('Р', 1), ('Б', 1)],
#  [('Н', 2), ('Р', 1)],
#  [('Ю', 3), ('Р', 2)],
#  [('Р', 2), ('Э', 1)],
#  [('Р', 2), ('Ь', 1)],
#  [('Р', 1), ('Ц', 1)],
#  [('Р', 2), ('Т', 1)],
#  [('Р', 1), ('Т', 1)],
#  [('Р', 1), ('Б', 1)],
#  [('Р', 2), ('Б', 1)],
#  [('Р', 1), ('А', 1)],
#  [('Р', 1), ('У', 1)],
#  [('П', 2), ('Р', 1)],
#  [('Р', 1), ('Ш', 1)],
#  [('Р', 2), (' ', 1)],
#  [('Р', 2), ('С', 1)],
#  [('Р', 1), ('Е', 1)],
#  [('Р', 1), ('Ж', 1)],
#  [('Р', 1), ('Ч', 1)],
#  [('Р', 1), ('Е', 1)],
#  [('Р', 1), ('Ю', 1)],
#  [('Р', 1), ('А', 1)],
#  [('Р', 2), ('Д', 1)],
#  [('Р', 3), ('Ю', 1)],
#  [('Р', 2), ('А', 1)],
#  [('Р', 1), ('Ю', 1)],
#  [('Р', 1), ('У', 1)],
#  [('Р', 2), ('Щ', 1)],
#  [('Х', 2), ('Р', 1)],
#  [('Р', 1), ('Д', 1)],
#  [('Р', 1), ('Я', 1)],
#  [('Р', 2), ('Т', 1)],
#  [('Р', 2), ('М', 1)],
#  [('Р', 1), ('Х', 1)],
#  [('Б', 2), ('Р', 1)],
#  [('Р', 1), ('С', 1)],
#  [('Р', 1), ('В', 1)],
#  [('Р', 1), (' ', 1)],
#  [('Р', 1), ('П', 1)],
#  [('Р', 1), ('Ш', 1)],
#  [('Р', 1), ('Ц', 1)],
#  [('Р', 1), ('Ю', 1)],
#  [('Р', 2), ('П', 1)],
#  [('Р', 1), ('Т', 1)],
#  [('Р', 1), ('Ж', 1)],
#  [('Р', 1), ('Ы', 1)],
#  [('Р', 2), ('У', 1)],
#  [('А', 2), ('Я', 2)],
#  [('Р', 1), ('Т', 1)],
#  [('Р', 1), ('Ж', 1)],
#  [('Р', 1), ('Б', 1)],
#  [('Р', 2), ('О', 1)],
#  [('Р', 1), ('Н', 1)],
#  [('Р', 2), ('Ю', 1)],
#  [('Р', 1), ('А', 1)],
#  [('У', 2), ('Р', 1)],
#  [('Р', 2), ('Г', 1)],
#  [('Р', 2), ('Л', 1)],
#  [('Р', 2), ('В', 1)],
#  [('Р', 1), ('Т', 1)],
#  [('Р', 1), ('Ю', 1)],
#  [('Р', 1), ('А', 1)],
#  [('Р', 2), ('А', 2)],
#  [('Р', 1), ('Ю', 1)],
#  [('А', 2), ('Р', 1)],
#  [('Р', 1), ('Я', 1)],
#  [('Р', 1), ('Г', 1)],
#  [('П', 2), ('Р', 1)],
#  [('Р', 1), ('С', 1)],
#  [('Р', 2), ('Ж', 1)],
#  [('Р', 1), ('Ю', 1)],
#  [('Р', 1), (' ', 1)],
#  [('Р', 1), ('П', 1)],
#  [('Р', 1), ('П', 1)],
#  [('Г', 2), ('Р', 1)],
#  [('Р', 2), ('А', 1)],
#  [('Р', 1), ('Ю', 1)],
#  [('Р', 1), ('Ж', 1)],
#  [('Р', 1), ('Ж', 1)],
#  [('Р', 1), ('Ж', 1)],
#  [('Р', 1), ('Ю', 1)],
#  [('Р', 1), ('Ы', 1)],
#  [('Р', 2), ('Й', 1)],
#  [('П', 2), ('Р', 1)],
#  [('Р', 1), ('И', 1)],
#  [('Р', 1), ('С', 1)],
#  [('Э', 2), ('Р', 1)],
#  [('Р', 1), ('П', 1)],
#  [('Р', 2), (' ', 1)],
#  [('Р', 1), ('Ж', 1)],
#  [('А', 2), ('Р', 1)],
#  [('Р', 1), ('Ш', 1)],
#  [('Р', 1), ('М', 1)],
#  [('Р', 1), ('К', 1)],
#  [('Ц', 2), ('Р', 1)],
#  [('Р', 2), (' ', 1)],
#  [('Ф', 2), ('Р', 1)],
#  [('Р', 1), ('П', 1)],
#  [('Р', 1), ('Ы', 1)],
#  [('Р', 1), ('Ж', 1)],
#  [('Р', 1), ('Ш', 1)],
#  [(' ', 2), ('Р', 1)],
#  [('Р', 1), ('Ж', 1)],
#  [('Р', 1), ('Щ', 1)],
#  [('Р', 1), ('А', 1)],
#  [('Ж', 2), ('Р', 1)],
#  [('Р', 1), ('У', 1)],
#  [('Р', 1), ('Л', 1)],
#  [('Р', 2), ('П', 1)],
#  [('Р', 1), ('У', 1)],
#  [('Р', 1), ('Я', 1)],
#  [('Р', 1), ('Т', 1)],
#  [('Р', 2), ('Н', 1)],
#  [('Р', 1), ('Ю', 1)],
#  [('Р', 1), ('И', 1)],
#  [('Р', 1), ('Я', 1)],
#  [('Р', 1), ('Ю', 1)],
#  [('Р', 1), ('Ж', 1)],
#  [('Р', 2), ('Щ', 1)],
#  [('Р', 1), ('А', 1)],
#  [('Р', 1), ('Щ', 1)],
#  [('Р', 1), ('Т', 1)],
#  [('Р', 1), ('У', 1)],
#  [('Ю', 2), ('Р', 1)],
#  [('Р', 1), ('Н', 1)],
#  [('Р', 1), ('Г', 1)],
#  [('Р', 1), ('Т', 1)],
#  [('Р', 2), ('Б', 1)],
#  [('Р', 2), ('Ю', 1)],
#  [('Р', 1), ('Е', 1)],
#  [('Р', 1), ('Я', 1)],
#  [('Р', 1), ('Ф', 1)],
#  [('Р', 1), ('О', 1)],
#  [('Р', 1), ('Ю', 1)],
#  [('Р', 1), ('Д', 1)],
#  [('Р', 1), ('Я', 1)],
#  [('Р', 1), ('Т', 1)],
#  [('Р', 2), ('П', 1)],
#  [('Р', 1), ('Э', 1)],
#  [('Р', 1), ('А', 1)],
#  [('Б', 2), ('Р', 1)],
#  [('Р', 1), ('Э', 1)],
#  [('Р', 1), ('П', 1)],
#  [('Р', 1), ('Э', 1)],
#  [('Р', 1), ('Ш', 1)],
#  [('Р', 1), ('С', 1)],
#  [('Р', 1), ('Ю', 1)],
#  [('Р', 2), ('Т', 1)],
#  [('Р', 1), ('О', 1)],
#  [('Р', 2), ('А', 1)],
#  [('Р', 1), ('Ю', 1)],
#  [('Р', 1), ('У', 1)],
#  [('Р', 1), ('А', 1)],
#  [('Ш', 2), ('Р', 1)],
#  [('Р', 1), ('П', 1)],
#  [('Р', 1), ('Щ', 1)],
#  [('Р', 1), ('З', 1)],
#  [('Р', 2), ('А', 1)],
#  [('Р', 1), (' ', 1)],
#  [('Р', 1), ('Ф', 1)],
#  [('Р', 1), ('Ы', 1)],
#  [('Р', 1), ('У', 1)],
#  [('Р', 1), ('Ц', 1)],
#  [('Р', 1), ('П', 1)],
#  [('Р', 1), ('О', 1)],
#  [('Р', 1), ('С', 1)],
#  [('Р', 1), ('Т', 1)],
#  [('Р', 1), ('Н', 1)],
#  [('Р', 1), ('П', 1)],
#  [('Р', 1), ('Д', 1)],
#  [('Р', 1), ('Я', 1)],
#  [('Р', 1), ('Ч', 1)],
#  [('Р', 1), ('Ф', 1)],
#  [('П', 2), ('Р', 1)],
#  [('Р', 1), ('П', 1)],
#  [('Р', 1), ('В', 1)],
#  [('Р', 1), ('Т', 1)],
#  [('Р', 1), ('С', 1)],
#  [('Р', 2), ('Ю', 1)],
#  [('Р', 1), ('З', 1)],
#  [('Р', 1), ('Х', 1)],
#  [('А', 2), ('Р', 1)],
#  [('Р', 2), ('О', 1)],
#  [('Р', 1), ('Ш', 1)],
#  [('Р', 2), (' ', 1)],
#  [('Р', 2), ('П', 1)],
#  [('Р', 1), ('Ы', 1)],
#  [('Р', 1), ('А', 1)],
#  [('Р', 1), ('Я', 1)],
#  [('Р', 1), ('П', 1)],
#  [('Р', 1), ('Е', 1)],
#  [('Р', 1), ('А', 1)],
#  [('Р', 1), ('С', 1)],
#  [('Р', 1), ('Ю', 1)],
#  [('Р', 1), ('О', 1)],
#  [('Р', 1), ('Ц', 1)],
#  [('Р', 1), (' ', 1)],
#  [('Р', 1), ('А', 1)],
#  [('Р', 2), ('Т', 1)],
#  [('Р', 1), ('А', 1)],
#  [('Р', 1), ('Ж', 1)],
#  [('Р', 1), ('Ш', 1)],
#  [('Р', 2), ('С', 1)],
#  [('Р', 1), ('Ъ', 1)],
#  [('Р', 1), ('Г', 1)],
#  [('Р', 1), ('Щ', 1)],
#  [('Р', 1), ('Т', 1)],
#  [('Р', 2), ('Т', 1)],
#  [('Р', 1), ('Х', 1)],
#  [('Р', 1), ('М', 1)],
#  [('Р', 1), ('С', 1)],
#  [('Р', 1), ('Т', 1)],
#  [('Р', 2), ('Д', 1)],
#  [('Р', 1), ('Ю', 1)],
#  [('Р', 1), ('С', 1)],
#  [('Р', 1), ('О', 1)],
#  [('Р', 1), ('З', 1)],
#  [('Р', 1), ('Й', 1)],
#  [('Э', 2), ('Р', 1)],
#  [('Р', 1), ('Б', 1)],
#  [('Р', 2), ('Й', 1)],
#  [('Р', 1), ('Ф', 1)],
#  [('Р', 1), ('М', 1)],
#  [('Р', 1), ('Ш', 1)],
#  [('Р', 1), ('И', 1)],
#  [('Р', 2), ('Й', 1)],
#  [('Р', 1), ('Б', 1)],
#  [('Р', 1), ('П', 1)],
#  [('Р', 1), ('Ъ', 1)],
#  [('Р', 2), ('П', 1)],
#  [('Р', 1), ('Ъ', 1)],
#  [('Р', 1), (' ', 1)],
#  [('Р', 1), ('Ь', 1)],
#  [('Р', 1), ('Д', 1)],
#  [('Р', 1), ('А', 1)],
#  [('Р', 1), ('Ц', 1)],
#  [('Р', 1), ('Ц', 1)],
#  [('Р', 1), ('П', 1)],
#  [('Р', 1), ('П', 1)],
#  [('Р', 1), ('С', 1)],
#  [('Р', 1), ('Я', 1)],
#  [('Р', 1), ('Ч', 1)],
#  [('Р', 1), ('Й', 1)],
#  [('Р', 1), ('Б', 1)],
#  [('Р', 1), ('Ж', 1)],
#  [('Р', 1), ('Ь', 1)],
#  [('Р', 1), ('Ш', 1)],
#  [('Р', 1), ('К', 1)],
#  [('Р', 1), ('П', 1)],
#  [('Р', 1), ('Й', 1)],
#  [('Р', 1), ('У', 1)],
#  [('Р', 1), ('У', 1)],
#  [('Р', 1), ('О', 1)],
#  [('Р', 1), ('П', 1)],
#  [('Р', 3)],
#  [('Р', 1), ('Ц', 1)],
#  [('Р', 1), ('Д', 1)],
#  [('Р', 1), ('С', 1)],
#  [('Р', 1), ('Ю', 1)],
#  [('Р', 1), ('Г', 1)],
#  [('Р', 1), ('Щ', 1)],
#  [('Р', 1), ('Й', 1)],
#  [('Р', 1), ('А', 1)],
#  [('Р', 1), ('С', 1)],
#  [('Р', 1), ('Ь', 1)],
#  [('Р', 1), ('Ь', 1)],
#  [('Р', 1), ('Т', 1)],
#  [('Р', 1), ('С', 1)],
#  [('Р', 1), ('Ю', 1)],
#  [('Р', 1), ('Т', 1)],
#  [('Р', 1), ('В', 1)],
#  [('Р', 1), ('Е', 1)],
#  [('Р', 1), ('А', 1)],
#  [('Р', 1), ('А', 1)],
#  [('Р', 1), ('С', 1)],
#  [('Р', 1), ('Ц', 1)],
#  [('Р', 1), ('Ч', 1)],
#  [('Р', 1), ('О', 1)],
#  [('Р', 1), ('Х', 1)],
#  [('Р', 1), ('Д', 1)],
#  [('Р', 1), ('Я', 1)],
#  [('Р', 1), ('Т', 1)],
#  [('Р', 1), ('Д', 1)],
#  [('Р', 1), ('Ы', 1)],
#  [('Р', 1), ('Б', 1)],
#  [('Р', 1), ('Ш', 1)],
#  [('Р', 1), ('У', 1)],
#  [('Р', 1), ('А', 1)],
#  [('Р', 1), ('Ш', 1)],
#  [('Р', 1), ('Н', 1)],
#  [('Р', 1), ('Ц', 1)],
#  [('Р', 1), ('Ю', 1)],
#  [('Р', 1), ('А', 1)],
#  [('Р', 2), ('А', 1)],
#  [('Р', 1), ('Ж', 1)],
#  [('Р', 1), ('А', 1)],
#  [('Р', 1), ('Н', 1)],
#  [('Р', 1), ('Ж', 1)],
#  [('Р', 1), ('П', 1)],
#  [('Р', 2), ('Г', 1)],
#  [('Р', 1), ('Я', 1)],
#  [('Р', 1), ('Ю', 1)],
#  [('Р', 1), ('П', 1)],
#  [('Р', 1), ('А', 1)],
#  [('Р', 1), ('Б', 1)],
#  [('Р', 2), ('П', 1)],
#  [('Р', 1), ('В', 1)],
#  [('Р', 1), ('Ф', 1)],
#  [('Р', 1), ('А', 1)],
#  [('Р', 1), ('Ь', 1)],
#  [('Р', 1), ('Ц', 1)],
#  [('Р', 1), ('Т', 1)],
#  [('Р', 1), ('О', 1)],
#  [('Р', 1), ('Ю', 1)],
#  [('Р', 1), ('Т', 1)],
#  [('Р', 2), ('А', 1)],
#  [('Р', 1), ('Б', 1)],
#  [('Р', 1), ('С', 1)],
#  [('Р', 1), ('О', 1)],
#  [('Р', 1), ('Н', 1)],
#  [('Р', 1), ('Я', 1)],
#  [('Р', 1), ('Ь', 1)],
#  [('Р', 1), ('А', 1)],
#  [('Р', 1), ('Ы', 1)],
#  [('Р', 1), ('Й', 1)],
#  [('Р', 1), ('Ж', 1)],
#  [('Р', 1), ('А', 1)],
#  [('Р', 1), ('Н', 1)],
#  [('П', 2), ('Р', 1)],
#  [('Р', 1), ('В', 1)],
#  [('Р', 1), ('Л', 1)],
#  [('Р', 1), ('Ю', 1)],
#  [('Р', 1), ('А', 1)],
#  [('Р', 2), ('С', 1)],
#  [('Р', 1), ('Ж', 1)],
#  [('Р', 1), ('Ь', 1)],
#  [('Р', 1), ('Т', 1)],
#  [('Р', 1), ('Й', 1)],
#  [('П', 2), ('Р', 1)],
#  [('Р', 1), ('Ц', 1)],
#  [('Р', 1), ('Г', 1)],
#  [('Р', 1), ('Ч', 1)],
#  [('Р', 1), ('П', 1)],
#  [('Р', 1), ('И', 1)],
#  [('Р', 1), ('Б', 1)],
#  [('Р', 1), ('У', 1)],
#  [('Р', 1), ('Т', 1)],
#  [('Р', 1), ('Г', 1)],
#  [('Р', 1), ('Ю', 1)],
#  [('Р', 2), ('У', 1)],
#  [('Р', 2), ('А', 1)],
#  [('Р', 1), ('Я', 1)],
#  [('Р', 1), ('Й', 1)],
#  [('Р', 1), ('Ы', 1)],
#  [('Р', 2), ('П', 1)],
#  [('Б', 2), ('Р', 1)],
#  [('Р', 1), ('Д', 1)],
#  [('Р', 1), ('Й', 1)],
#  [('Р', 1), ('Т', 1)],
#  [('Р', 1), ('Ь', 1)],
#  [('Р', 2), ('Ъ', 1)],
#  [('Р', 1), ('Т', 1)],
#  [('Р', 1), ('Д', 1)],
#  [('Р', 1), ('Ю', 1)],
#  [('Р', 2), ('Т', 1)],
#  [('Р', 1), ('Г', 1)],
#  [('Р', 1), ('Ч', 1)],
#  [('Р', 1), ('Б', 1)],
#  [('Р', 1), (' ', 1)],
#  [('Р', 1), ('Э', 1)],
#  [('Р', 2), ('Б', 1)],
#  [('Р', 1), ('Я', 1)],
#  [('Р', 1), ('П', 1)],
#  [('Р', 1), ('Щ', 1)],
#  [('Р', 1), ('А', 1)],
#  [('Р', 1), ('У', 1)],
#  [('Р', 1), ('Г', 1)],
#  [('Р', 1), ('Э', 1)],
#  [('Р', 1), ('П', 1)],
#  [('Р', 2), ('Ш', 1)],
#  [('Р', 1), ('В', 1)],
#  [('Р', 1), ('А', 1)],
#  [('А', 2), ('Р', 1)],
#  [('Р', 1), ('Ь', 1)],
#  [('Р', 1), ('П', 1)],
#  [('Р', 1), ('Ф', 1)],
#  [('Р', 1), ('Т', 1)],
#  [('Р', 1), (' ', 1)],
#  [('Р', 1), ('П', 1)],
#  [('Р', 2), ('Я', 1)],
#  [('Р', 1), ('А', 1)],
#  [('Р', 1), ('Ы', 1)],
#  [('Р', 2), (' ', 1)],
#  [('Р', 1), ('Ю', 1)],
#  [('Р', 1), ('Н', 1)],
#  [('Р', 1), ('Ю', 1)],
#  [('Р', 1), ('Ы', 1)],
#  [('Р', 1), ('У', 1)],
#  [('Р', 1), ('Л', 1)],
#  [('Р', 2), ('А', 1)],
#  [('Р', 1), ('Ы', 1)],
#  [('Р', 1), ('У', 1)],
#  [('Р', 1), ('Т', 1)],
#  [('Р', 2), ('К', 1)],
#  [('Р', 2), ('У', 1)],
#  [('Р', 1), ('Ц', 1)],
#  [('Р', 1), ('Ю', 1)],
#  [('Р', 1), ('Э', 1)],
#  [('Р', 1), ('Э', 1)],
#  [('Р', 1), ('П', 1)],
#  [('Р', 2), ('А', 1)],
#  [('А', 2), ('Р', 1)],
#  [('Р', 1), ('В', 1)],
#  [('Р', 1), (' ', 1)],
#  [('Р', 1), ('Б', 1)],
#  [('Р', 1), ('Ш', 1)],
#  [('Р', 1), ('У', 1)],
#  [('Р', 1), ('А', 1)],
#  [('Р', 1), ('Ц', 1)],
#  [('Р', 1), ('Й', 1)],
#  [('Р', 1), ('Ш', 1)],
#  [('Р', 1), (' ', 1)],
#  [('Р', 1), ('Й', 1)],
#  [('Р', 1), ('П', 1)],
#  [('Р', 1), ('И', 1)],
#  [('Р', 2), ('С', 1)],
#  [('Р', 1), (' ', 1)],
#  [('Р', 1), (' ', 1)],
#  [('Р', 1), ('Б', 1)],
#  [('Р', 1), ('Й', 1)],
#  [('Р', 1), ('Ъ', 1)],
#  [('Р', 1), ('Т', 1)],
#  [('Р', 1), ('О', 1)],
#  [('Р', 1), (' ', 1)],
#  [('Р', 2), ('Б', 1)],
#  [('Р', 1), ('У', 1)],
#  [('У', 2), ('Р', 1)],
#  [('Р', 1), ('А', 1)],
#  [('Р', 1), ('Ш', 1)],
#  [('Р', 1), ('А', 1)],
#  [('Р', 1), ('Ю', 1)],
#  [('Р', 1), ('У', 1)],
#  [('Р', 1), ('С', 1)],
#  [('Р', 1), ('В', 1)],
#  [('Р', 1), ('З', 1)],
#  [('Р', 1), ('Ю', 1)],
#  [('Р', 1), ('А', 1)],
#  [('Р', 1), ('Т', 1)],
#  [('Р', 1), ('Б', 1)],
#  [('Р', 1), ('Й', 1)],
#  [('Р', 2), ('У', 1)],
#  [('Р', 1), ('Б', 1)],
#  [('Р', 1), ('П', 1)],
#  [('Р', 1), ('Ъ', 1)],
#  [('Р', 2), ('П', 1)],
#  [('Р', 1), ('Ъ', 1)],
#  [('Р', 1), (' ', 1)],
#  [('Р', 1), ('П', 1)],
#  [('Р', 1), ('У', 1)],
#  [('Р', 1), ('П', 1)],
#  [('Р', 2), ('Б', 1)],
#  [('Р', 1), ('Г', 1)],
#  [('Р', 1), ('П', 1)],
#  [('Р', 1), ('А', 1)],
#  [('Р', 1), ('Ж', 1)],
#  [('Р', 1), ('Х', 1)],
#  [('Р', 1), ('У', 1)],
#  [('Р', 1), ('А', 1)],
#  [('Р', 1), ('Ш', 1)],
#  [('Р', 1), ('А', 1)],
#  [('Р', 1), (' ', 1)],
#  [('Р', 1), ('В', 1)],
#  [('Р', 1), ('Й', 1)],
#  [('Р', 1), ('О', 1)],
#  [('Р', 1), ('У', 1)],
#  [('Р', 1), ('Ц', 1)],
#  [('Р', 1), ('Ю', 1)],
#  [('Р', 1), (' ', 1)],
#  [('Р', 1), ('П', 1)],
#  [('Р', 1), ('Н', 1)],
#  [('Р', 1), ('Я', 1)],
#  [('Р', 1), ('Ш', 1)],
#  [('Р', 1), ('Д', 1)],
#  [('Р', 1), ('Ю', 1)],
#  [('Р', 1), ('А', 1)],
#  [('Р', 1), ('Ю', 1)],
#  [('Р', 1), ('А', 1)],
#  [('Р', 1), ('А', 1)],
#  [('Р', 1), ('Т', 1)],
#  [('Р', 1), ('А', 1)],
#  [('Р', 1), ('Б', 1)],
#  [('Р', 1), ('Ю', 1)],
#  [('Р', 1), ('Ф', 1)],
#  [('Р', 1), ('Ж', 1)],
#  [('Р', 1), ('Б', 1)],
#  [('Р', 1), ('Ц', 1)],
#  [('Р', 1), ('Т', 1)],
#  [('Р', 1), ('Ж', 1)],
#  [('Р', 1), ('А', 1)],
#  [('Р', 1), ('М', 1)],
#  [('Р', 1), ('Щ', 1)],
#  [('Р', 1), ('Т', 1)],
#  [('Р', 1), ('И', 1)],
#  [('Р', 2)],
#  [('Р', 1), ('В', 1)],
#  [('Р', 1), ('Ь', 1)],
#  [('Р', 1), ('У', 1)],
#  [('Р', 1), ('Д', 1)],
#  [('Р', 1), ('Ю', 1)],
#  [('Р', 1), ('С', 1)],
#  [('Р', 1), ('С', 1)],
#  [('Р', 1), ('Г', 1)],
#  [('Р', 1), ('Т', 1)],
#  [('Р', 1), ('В', 1)],
#  [('Р', 1), ('Е', 1)],
#  [('Р', 1), ('Щ', 1)],
#  [('Р', 1), ('Д', 1)],
#  [('Р', 1), ('Ж', 1)],
#  [('Р', 1), ('П', 1)],
#  [('Р', 1), ('Т', 1)],
#  [('Р', 1), ('Х', 1)],
#  [('Р', 1), ('Ш', 1)],
#  [('Р', 1), ('М', 1)],
#  [('Р', 2)],
#  [('Р', 1), ('У', 1)],
#  [('Р', 1), ('М', 1)],
#  [('Р', 1), ('Т', 1)],
#  [('Р', 1), ('Й', 1)],
#  [('Р', 1), ('Ч', 1)],
#  [('Р', 1), ('А', 1)],
#  [('Р', 1), ('Б', 1)],
#  [('Р', 1), ('Ш', 1)],
#  [('Р', 1), ('Д', 1)],
#  [('Р', 1), ('Ю', 1)],
#  [('Р', 1), ('А', 1)],
#  [('Р', 1), ('Э', 1)],
#  [('Р', 1), ('А', 1)],
#  [('Р', 1), ('Ж', 1)],
#  [('Р', 1), ('У', 1)],
#  [('Р', 1), ('П', 1)],
#  [('Р', 2)],
#  [('Р', 1), ('Б', 1)],
#  [('Р', 1), ('Й', 1)],
#  [('Р', 1), ('А', 1)],
#  [('Р', 1), ('Э', 1)],
#  [('Р', 1), ('Э', 1)],
#  [('Р', 1), ('У', 1)],
#  [('Р', 1), ('А', 1)],
#  [('Р', 1), ('Ъ', 1)],
#  [('Р', 1), ('Б', 1)],
#  [('Р', 1), ('Ы', 1)],
#  [('Р', 1), ('А', 1)],
#  [('Р', 1), ('Ж', 1)],
#  [('Р', 1), ('П', 1)],
#  [('Р', 1), ('М', 1)],
#  [('Р', 1), ('Щ', 1)],
#  [('Р', 1), ('Ф', 1)],
#  [('Р', 1), ('П', 1)],
#  [('Р', 1), ('П', 1)],
#  [('Р', 1), ('Ф', 1)],
#  [('Р', 1), (' ', 1)],
#  [('Р', 1), ('А', 1)],
#  [('Р', 1), ('У', 1)],
#  [('Р', 1), (' ', 1)],
#  [('Р', 1), ('Ж', 1)],
#  [('Р', 1), ('Т', 1)],
#  [('Р', 1), ('Ю', 1)],
#  [('Р', 1), ('Ж', 1)],
#  [('Р', 1), ('Э', 1)],
#  [('Р', 1), ('Й', 1)],
#  [('Р', 1), ('Ц', 1)],
#  [('Р', 1), ('Т', 1)],
#  [('Р', 1), ('Г', 1)],
#  [('Р', 1), ('А', 1)],
#  [('Р', 1), ('Ж', 1)],
#  [('Р', 1), (' ', 1)],
#  [('Р', 1), ('А', 1)],
#  [('Р', 1), ('Л', 1)],
#  [('Р', 1), ('Ю', 1)],
#  [('Р', 1), ('С', 1)],
#  [('Р', 1), ('Ю', 1)],
#  [('Р', 1), ('Ш', 1)],
#  [('Р', 1), ('К', 1)],
#  [('Р', 1), ('З', 1)],
#  [('Р', 1), ('Ж', 1)],
#  [('Р', 2)],
#  [('Р', 1), ('Б', 1)],
#  [('Р', 1), ('С', 1)],
#  [('Р', 1), ('Ю', 1)],
#  [('Р', 1), ('Щ', 1)],
#  [('Р', 1), ('Г', 1)],
#  [('Р', 1), ('Т', 1)],
#  [('Р', 1), ('О', 1)],
#  [('Р', 1), ('Ш', 1)],
#  [('Р', 1), ('Л', 1)],
#  [('Р', 1), ('С', 1)],
#  [('Р', 1), ('Э', 1)],
#  [('Р', 1), ('А', 1)],
#  [('Р', 1), ('Ш', 1)],
#  [('Р', 1), ('Н', 1)],
#  [('Р', 1), ('Ц', 1)],
#  [('Р', 1), (' ', 1)],
#  [('Р', 1), ('Й', 1)],
#  [('Р', 1), ('П', 1)],
#  [('Р', 1), ('Н', 1)],
#  [('Р', 1), ('Я', 1)],
#  [('Р', 1), ('Ш', 1)],
#  [('Р', 1), ('Д', 1)],
#  [('Р', 1), ('Ю', 1)],
#  [('Р', 1), ('А', 1)],
#  [('Р', 1), ('Ю', 1)],
#  [('Р', 1), ('Ш', 1)],
#  [('Р', 1), ('А', 1)],
#  [('Р', 1), ('В', 1)],
#  [('Р', 2)],
#  [('Р', 1), ('Я', 1)],
#  [('Р', 1), ('Я', 1)],
#  [('Р', 1), ('Й', 1)],
#  [('Р', 1), ('Э', 1)],
#  [('Р', 1), ('Б', 1)],
#  [('Р', 1), ('В', 1)],
#  [('Р', 1), ('О', 1)],
#  [('Р', 1), ('А', 1)],
#  [('Р', 1), ('Ш', 1)],
#  [('Р', 1), ('В', 1)],
#  [('Р', 1), ('Я', 1)],
#  [('Р', 1), ('Т', 1)],
#  [('Р', 1), ('Ц', 1)],
#  [('Р', 1), ('Ю', 1)],
#  [('Р', 1), ('У', 1)],
#  [('Р', 1), ('П', 1)],
#  [('Р', 1), ('Т', 1)],
#  [('Р', 1), (' ', 1)],
#  [('Р', 1), ('П', 1)],
#  [('Р', 1), ('Г', 1)],
#  [('Р', 1), ('Ц', 1)],
#  [('Р', 1), ('Г', 1)],
#  [('Р', 1), ('Э', 1)],
#  [('Р', 1), ('Ь', 1)],
#  [('Р', 1), ('Б', 1)],
#  [('Р', 2)],
#  [('Р', 1), ('Е', 1)],
#  [('Р', 1), ('Г', 1)],
#  [('Р', 2)],
#  [('Р', 1), ('З', 1)],
#  [('Р', 1), ('С', 1)],
#  [('Р', 2)],
#  [('Р', 1), ('А', 1)],
#  [('Р', 1), ('Ш', 1)],
#  [('Р', 1), ('А', 1)],
#  [('Р', 1), ('Ь', 1)],
#  [('Р', 2)],
#  [('Р', 1), ('В', 1)],
#  [('Р', 1), ('Ы', 1)],
#  [('Р', 1), ('Я', 1)],
#  [('Р', 2)],
#  [('Р', 1), ('Г', 1)],
#  [('Р', 1), ('П', 1)],
#  [('Р', 1), ('Ж', 1)],
#  [('Р', 1), ('Й', 1)],
#  [('Р', 1), ('Ю', 1)],
#  [('Р', 1), ('Ы', 1)],
#  [('Р', 1), ('У', 1)],
#  [('Р', 1), ('Х', 1)],
#  [('Р', 1), ('М', 1)],
#  [('Р', 1), ('Ц', 1)],
#  [('Р', 1), ('Ь', 1)],
#  [('Р', 1), ('А', 1)],
#  [('Р', 1), ('Э', 1)],
#  [('Р', 1), ('П', 1)],
#  [('Р', 2)],
#  [('Р', 1), ('Х', 1)],
#  [('Р', 1), ('А', 1)],
#  [('Р', 1), ('А', 1)],
#  [('Р', 1), ('Й', 1)],
#  [('Р', 1), ('Ц', 1)],
#  [('Р', 1), ('Т', 1)],
#  [('Р', 1), ('И', 1)],
#  [('Р', 1), ('Т', 1)],
#  [('Р', 1), ('Б', 1)],
#  [('Р', 1), ('Ю', 1)],
#  [('Р', 1), ('Ы', 1)],
#  [('Р', 1), ('Ж', 1)],
#  [('Р', 1), ('П', 1)],
#  [('Р', 1), ('Г', 1)],
#  [('Р', 1), ('Б', 1)],
#  [('Р', 1), ('Д', 1)],
#  [('Р', 1), ('Ф', 1)],
#  [('Р', 1), ('Я', 1)],
#  [('Р', 1), ('Й', 1)],
#  [('Р', 1), ('В', 1)],
#  [('Р', 1), ('О', 1)],
#  [('Р', 1), ('А', 1)],
#  [('Р', 1), ('Я', 1)],
#  [('Р', 1), ('П', 1)],
#  [('Р', 1), ('Ь', 1)],
#  [('Р', 1), ('У', 1)],
#  [('Р', 1), ('Д', 1)],
#  [('Р', 2)],
#  [('Р', 1), ('Я', 1)],
#  [('Р', 2)],
#  [('Р', 1), ('Ы', 1)],
#  [('Р', 1), ('И', 1)],
#  [('Р', 1), ('Ы', 1)],
#  [('Р', 1), ('Й', 1)],
#  [('Р', 1), ('И', 1)],
#  [('Р', 1), (' ', 1)],
#  [('Р', 1), ('Й', 1)],
#  [('Р', 1), ('Ь', 1)],
#  [('Р', 1), ('А', 1)],
#  [('Р', 1), ('Щ', 1)],
#  [('Р', 1), ('Т', 1)],
#  [('Р', 1), ('Г', 1)],
#  [('Р', 1), ('П', 1)],
#  ...]

# %%
case[4::5]
# Out:
# 'И АСЭНГЙЩПЕУА ЖДПНБАИАУДЛМОЖОЙЖПЕУПЗААППЯБЖРФАСЯБЖГ ЙСТ ОРТОЖДЩМ ПАНЛДППЖЙПМПЖЛНЖУРОППТААЦНФСОАСАСТДЙМПЬПЙКОСАСАОДААЖПФОСАНАЙПГЙЙДБПЭА РУТЭВАЙ ОАСТПППАЙ ДАФЖИДТЖМЙДЖЙАЖПУЖГЛКСОАЙДАЙАЦ ЭГАВПУААИЖФАДИЙГААЙЬЙОППЙАААСМОПМУЛЛАЖЖАДДМНПФЖУ АЙАПУПБАБСБЛГЖИШГПМСЙАЙБЗРУФББРПЩОУПАЬАИЖБОФЙАНАТНАРЦТМНУСБВНУОПЙБАС'

# %%
p = 5
for i in range(p):
    print(sorted(collections.Counter(case[i::p]).items(), 
                 key=lambda item: item[1], reverse=True)[0])
# Out:
# ('П', 54)
# ('А', 38)
# ('Р', 42)
# ('Т', 54)
# ('А', 48)

# %%
case[::5]
# Out:
# 'РТПШХПАРЧХЪЪЖШПТФПОПЯЮЭПЮЮШРЭЮЭЭБЮЪЮХШЯТАППЬ ФЫРПБНПЖППЬПХЭБШЧЮХХПТТРВЮСПЖП КЫЩПЮЩЮЮЮЭЭОЬ ПППЮШЯЮТЪХЮЭШЪДПБППЮСЮАХЫШАПААЮОЫПСПИЮЫТЮ ЩПЬПЮЛРЭ ЦПБ ШВБЪУАШОПЮТЖАРЮВПРЧЮУАЪПП ЭАЮЗЮШШПЮВЭШЮПЬРШЫЖХЭАТПЯЯРЫЬПЫЭЫЬАКШЖХЯУЭОЮРТХПФЮЬПИЯРЮШПЖТЬРПЮЖЯАХУЬШПЮПШППРРПЬХВАСЭФФЮШЪТПШПЭЮПЩЮПШТПУКЪЬШШТКПЫКПЪХЮХРЧКВВКТЪПТХ'

# %%
for enum, i in enumerate(sorted(ALHAVIT)):
    print(enum, i)
# Out:
# 0
# 1 А
# 2 Б
# 3 В
# 4 Г
# 5 Д
# 6 Е
# 7 Ж
# 8 З
# 9 И
# 10 Й
# 11 К
# 12 Л
# 13 М
# 14 Н
# 15 О
# 16 П
# 17 Р
# 18 С
# 19 Т
# 20 У
# 21 Ф
# 22 Х
# 23 Ц
# 24 Ч
# 25 Ш
# 26 Щ
# 27 Ъ
# 28 Ы
# 29 Ь
# 30 Э
# 31 Ю
# 32 Я

# %%
def kod(s):
    if s == ' ':
        return 0
    return ord(s) - ord('А') + 1


def re(k):
    if k == 0:
        return ' '
    return chr(ord('А') + k - 1)


k = [16, 1, 17, 19, 1]
cc = ''
j = 0
for i in case:
    cc += re((kod(i) + 33 - k[j % 5]) % 33)
    j += 1

# %%
cc
# Out:
# 'А НАЗВАНИЯ СЕЛ И ДЕРЕВЕНЬ ЗАИМСТВОВАНЫ ИЗ НАШЕГО ОКОЛОДКА ОТЧЕГО И МОЯ ДЕРЕВНЯ ГДЕ ТО УПОМЯНУТА СИЕ ПРОИЗОШЛО НЕ ОТ ЗЛОГО КАКОГО ЛИБО НАМЕРЕНИЯ НО ЕДИНСТВЕННО ОТ НЕДОСТАТКА ВООБРАЖЕНИЯ ИВАН ПЕТРОВИЧ ОСЕНЬЮ ГОДА ЗАНЕМОГ ПРОСТУДНОЮ ЛИХОРАДКОЮ ОБРАТИВШЕЮСЯ В ГОРЯЧКУ И УМЕР НЕ СМОТРЯ НА НЕУСЫПНЫЕ СТАРАНИЯ УЕЗДНОГО НАШЕГО ЛЕКАРЯ ЧЕЛОВЕКА ВЕСЬМА ИСКУСНОГО ОСОБЕННО В ЛЕЧЕНИИ ЗАКОРЕНЕЛЫХ БОЛЕЗНЕЙ КАК ТО МОЗОЛЕЙ И ТОМУ ПОДОБНОГО ОН СКОНЧАЛСЯ НА МОИХ РУКАХ НА М ГОДУ ОТ РОЖДЕНИЯ И ПОХОРОНЕН В ЦЕРКВИ СЕЛА ГОРЮХИНА БЛИЗ ПОКОЙНЫХ ЕГО РОДИТЕЛЕЙ ИВАН ПЕТРОВИЧ БЫЛ РОСТУ СРЕДНЕГО ГЛАЗА ИМЕЛ СЕРЫЕ ВОЛОСА РУСЫЕ НОС ПРЯМОЙ ЛИЦОМ БЫЛ БЕЛ И ХУДОЩАВ ВОТ МИЛОСТИВЫЙ ГОСУДАРЬ МОЙ ВСЬ ЧТО МОГ Я ПРИПОМНИТЬ КАСАТЕЛЬНО ОБРАЗА ЖИЗНИ ЗАНЯТИЙ НРАВА И НАРУЖНОСТИ ПОКОЙНОГО СОСЕДА И ПРИЯТЕЛЯ МОЕГО НО В СЛУЧАЕ ЕСЛИ ЗАБЛАГОРАССУДИТЕ СДЕЛАТЬ ИЗ СЕГО МОЕГО ПИСЬМА КАКОЕ ЛИБО УПОТРЕБЛЕНИЕ ВСЕПОКОРНЕЙШЕ ПРОШУ НИКАК ИМЕНИ МОЕГО НЕ УПОМИНАТЬ ИБО ХОТЯ Я ВЕСЬМА УВАЖАЮ И ЛЮБЛЮ СОЧИНИТЕЛЕЙ НО В СИЕ ЗВАНИЕ ВСТУПИТЬ ПОЛАГАЮ ИЗЛИШНИМ И В МОИ ЛЕТА НЕПРИЛИЧНЫМ С ИСТИННЫМ МОИМ ПОЧТЕНИЕМ И ПРОЧ ГОДУ НОЯБРЯ СЕЛО НЕНАРАДОВО СЛЕДУЕТ АНЕКДОТ КОЕГО МЫ НЕ ПОМЕЩАЕМ ПОЛАГАЯ ЕГО ИЗЛИШНИМ ВПРОЧЕМ УВЕРЯЕМ ЧИТАТЕЛЯ ЧТО ОН НИЧЕГО ПРЕДОСУДИТЕЛЬНОГО ПАМЯТИ ИВАНА ПЕТРОВИЧА БЕЛКИНА В СЕБЕ НЕ ЗАКЛЮЧАЕТ В САМОМ ДЕЛЕ В РУКОПИСИ Г БЕЛКИНА НАД КАЖДОЙ ПОВЕСТИЮ РУКОЮ АВТОРА НАДПИСАНО СЛЫШНО МНОЮ ОТ ТАКОЙ ТО ОСОБЫ ЧИН ИЛИ ЗВАНИЕ И ЗАГЛАВНЫЕ БУКВЫ ИМЕНИ И ФАМИЛИИ ВЫПИСЫВАЕМ ДЛЯ ЛЮБОПЫТНЫХ ИЗЫСКАТЕЛЕЙ СМОТРИТЕЛЬ РАССКАЗАН БЫЛ ЕМУ ТИТУЛЯРНЫМ СОВЕТНИКОМ А Г Н ВЫСТРЕЛ'

# %%
# with open('decase5.txt', 'w') as ff:
#     ff.write(cc)

# %%
# with open('ccase5.txt', 'w') as ff:
#     ff.write(case)
